# %%
import requests
import json
import os
import datetime

session = requests.Session()

# %%
# bootstrap-static
bootstrap_static = json.loads(session.get('https://fantasy.premierleague.com/api/bootstrap-static/').text)
bootstrap_static["_id"] = datetime.datetime.utcnow()
fixtures = json.loads(session.get('https://fantasy.premierleague.com/api/fixtures/').text)

# %%
fixtures[3]
# Out:
# {'code': 2128287,
#  'event': 1,
#  'finished': True,
#  'finished_provisional': True,
#  'id': 1,
#  'kickoff_time': '2020-09-12T14:00:00Z',
#  'minutes': 90,
#  'provisional_start_time': False,
#  'started': True,
#  'team_a': 16,
#  'team_a_score': 0,
#  'team_h': 6,
#  'team_h_score': 1,
#  'stats': [{'identifier': 'goals_scored',
#    'a': [],
#    'h': [{'value': 1, 'element': 141}]},
#   {'identifier': 'assists', 'a': [], 'h': [{'value': 1, 'element': 137}]},
#   {'identifier': 'own_goals', 'a': [], 'h': []},
#   {'identifier': 'penalties_saved', 'a': [], 'h': []},
#   {'identifier': 'penalties_missed', 'a': [], 'h': []},
#   {'identifier': 'yellow_cards',
#    'a': [{'value': 1, 'element': 375}],
#    'h': [{'value': 1, 'element': 131}, {'value': 1, 'element': 142}]},
#   {'identifier': 'red_cards', 'a': [], 'h': []},
#   {'identifier': 'saves',
#    'a': [{'value': 2, 'element': 363}],
#    'h': [{'value': 5, 'element': 128}]},
#   {'identifier': 'bonus',
#    'a': [],
#    'h': [{'value': 3, 'element': 128},
#     {'value': 2, 'element': 137},
#     {'value': 1, 'element': 486}]},
#   {'identifier': 'bps',
#    'a': [{'value': 19, 'element': 369},
#     {'value': 17, 'element': 363},
#     {'value': 15, 'element': 362},
#     {'value': 15, 'element': 370},
#     {'value': 13, 'element': 364},
#     {'value': 12, 'element': 367},
#     {'value': 12, 'element': 375},
#     {'value': 11, 'element': 376},
#     {'value': 5, 'element': 365},
#     {'value': 4, 'element': 361},
#     {'value': 4, 'element': 379},
#     {'value': 4, 'element': 382},
#     {'value': 3, 'element': 377},
#     {'value': 1, 'element': 366}],
#    'h': [{'value': 31, 'element': 128},
#     {'value': 26, 'element': 137},
#     {'value': 24, 'element': 486},
#     {'value': 23, 'element': 146},
#     {'value': 22, 'element': 134},
#     {'value': 18, 'element': 141},
#     {'value': 14, 'element': 130},
#     {'value': 6, 'element': 138},
#     {'value': 5, 'element': 131},
#     {'value': 3, 'element': 133},
#     {'value': 3, 'element': 142},
#     {'value': 3, 'element': 489},
#     {'value': -7, 'element': 140}]}],
#  'team_h_difficulty': 2,
#  'team_a_difficulty': 3,
#  'pulse_id': 58897}

# %%
bootstrap_static.keys()
# Out:
# dict_keys(['events', 'game_settings', 'phases', 'teams', 'total_players', 'elements', 'element_stats', 'element_types', '_id'])

# %%
bootstrap_static.keys()
# Out:
# dict_keys(['events', 'game_settings', 'phases', 'teams', 'total_players', 'elements', 'element_stats', 'element_types', '_id'])

# %% [markdown]
# ## Description of the file
# 'events' : gameweek
# 'game_settings'

# %%
bootstrap_static['events']
# Out:
# ing_entry': 6563000,
#   'deadline_time_epoch': 1601719200,
#   'deadline_time_game_offset': 0,
#   'highest_score': 160,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'chip_plays': [{'chip_name': 'bboost', 'num_played': 82267},
#    {'chip_name': 'freehit', 'num_played': 131861},
#    {'chip_name': 'wildcard', 'num_played': 420437},
#    {'chip_name': '3xc', 'num_played': 171134}],
#   'most_selected': 272,
#   'most_transferred_in': 164,
#   'top_element': 37,
#   'top_element_info': {'id': 37, 'points': 24},
#   'transfers_made': 14570655,
#   'most_captained': 254,
#   'most_vice_captained': 272},
#  {'id': 5,
#   'name': 'Gameweek 5',
#   'deadline_time': '2020-10-17T10:00:00Z',
#   'average_entry_score': 60,
#   'finished': True,
#   'data_checked': True,
#   'highest_scoring_entry': 7124486,
#   'deadline_time_epoch': 1602928800,
#   'deadline_time_game_offset': 0,
#   'highest_score': 136,
#   'is_previous': True,
#   'is_current': False,
#   'is_next': False,
#   'chip_plays': [{'chip_name': 'bboost', 'num_played': 80554},
#    {'chip_name': 'freehit', 'num_played': 161926},
#    {'chip_name': 'wildcard', 'num_played': 599860},
#    {'chip_name': '3xc', 'num_played': 114707}],
#   'most_selected': 164,
#   'most_transferred_in': 390,
#   'top_element': 117,
#   'top_element_info': {'id': 117, 'points': 16},
#   'transfers_made': 18391649,
#   'most_captained': 390,
#   'most_vice_captained': 254},
#  {'id': 6,
#   'name': 'Gameweek 6',
#   'deadline_time': '2020-10-23T17:30:00Z',
#   'average_entry_score': 48,
#   'finished': True,
#   'data_checked': True,
#   'highest_scoring_entry': 4289106,
#   'deadline_time_epoch': 1603474200,
#   'deadline_time_game_offset': 0,
#   'highest_score': 123,
#   'is_previous': False,
#   'is_current': True,
#   'is_next': False,
#   'chip_plays': [{'chip_name': 'bboost', 'num_played': 58697},
#    {'chip_name': 'freehit', 'num_played': 118050},
#    {'chip_name': 'wildcard', 'num_played': 384670},
#    {'chip_name': '3xc', 'num_played': 160028}],
#   'most_selected': 164,
#   'most_transferred_in': 388,
#   'top_element': 202,
#   'top_element_info': {'id': 202, 'points': 17},
#   'transfers_made': 12707803,
#   'most_captained': 254,
#   'most_vice_captained': 390},
#  {'id': 7,
#   'name': 'Gameweek 7',
#   'deadline_time': '2020-10-30T18:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1604082600,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': True,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 8,
#   'name': 'Gameweek 8',
#   'deadline_time': '2020-11-06T18:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1604687400,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 9,
#   'name': 'Gameweek 9',
#   'deadline_time': '2020-11-21T11:00:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1605956400,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 10,
#   'name': 'Gameweek 10',
#   'deadline_time': '2020-11-28T11:00:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1606561200,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 11,
#   'name': 'Gameweek 11',
#   'deadline_time': '2020-12-05T13:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1607175000,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 12,
#   'name': 'Gameweek 12',
#   'deadline_time': '2020-12-12T13:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1607779800,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 13,
#   'name': 'Gameweek 13',
#   'deadline_time': '2020-12-15T18:15:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1608056100,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 14,
#   'name': 'Gameweek 14',
#   'deadline_time': '2020-12-19T13:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1608384600,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 15,
#   'name': 'Gameweek 15',
#   'deadline_time': '2020-12-26T13:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1608989400,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 16,
#   'name': 'Gameweek 16',
#   'deadline_time': '2020-12-28T13:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1609162200,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 17,
#   'name': 'Gameweek 17',
#   'deadline_time': '2021-01-02T13:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1609594200,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 18,
#   'name': 'Gameweek 18',
#   'deadline_time': '2021-01-12T18:15:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1610475300,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 19,
#   'name': 'Gameweek 19',
#   'deadline_time': '2021-01-16T13:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1610803800,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 20,
#   'name': 'Gameweek 20',
#   'deadline_time': '2021-01-26T18:15:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1611684900,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 21,
#   'name': 'Gameweek 21',
#   'deadline_time': '2021-01-30T13:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1612013400,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 22,
#   'name': 'Gameweek 22',
#   'deadline_time': '2021-02-02T18:15:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1612289700,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 23,
#   'name': 'Gameweek 23',
#   'deadline_time': '2021-02-06T13:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1612618200,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 24,
#   'name': 'Gameweek 24',
#   'deadline_time': '2021-02-13T13:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1613223000,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 25,
#   'name': 'Gameweek 25',
#   'deadline_time': '2021-02-20T13:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1613827800,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 26,
#   'name': 'Gameweek 26',
#   'deadline_time': '2021-02-27T13:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1614432600,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 27,
#   'name': 'Gameweek 27',
#   'deadline_time': '2021-03-06T13:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1615037400,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 28,
#   'name': 'Gameweek 28',
#   'deadline_time': '2021-03-13T13:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1615642200,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 29,
#   'name': 'Gameweek 29',
#   'deadline_time': '2021-03-20T13:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1616247000,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 30,
#   'name': 'Gameweek 30',
#   'deadline_time': '2021-04-03T12:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1617453000,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 31,
#   'name': 'Gameweek 31',
#   'deadline_time': '2021-04-10T12:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1618057800,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 32,
#   'name': 'Gameweek 32',
#   'deadline_time': '2021-04-17T12:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1618662600,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 33,
#   'name': 'Gameweek 33',
#   'deadline_time': '2021-04-24T12:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1619267400,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 34,
#   'name': 'Gameweek 34',
#   'deadline_time': '2021-05-01T12:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1619872200,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 35,
#   'name': 'Gameweek 35',
#   'deadline_time': '2021-05-08T12:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1620477000,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 36,
#   'name': 'Gameweek 36',
#   'deadline_time': '2021-05-11T17:15:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1620753300,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 37,
#   'name': 'Gameweek 37',
#   'deadline_time': '2021-05-15T12:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1621081800,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 38,
#   'name': 'Gameweek 38',
#   'deadline_time': '2021-05-23T13:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1621776600,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None}]

# %%
[(el['name'],el['strength_defence_home']) for el in bootstrap_static['teams']]
# Out:
# [('Arsenal', 1190),
#  ('Aston Villa', 1120),
#  ('Brighton', 1100),
#  ('Burnley', 1010),
#  ('Chelsea', 1230),
#  ('Crystal Palace', 1020),
#  ('Everton', 1210),
#  ('Fulham', 1000),
#  ('Leicester', 1200),
#  ('Leeds', 1100),
#  ('Liverpool', 1320),
#  ('Man City', 1330),
#  ('Man Utd', 1200),
#  ('Newcastle', 1030),
#  ('Sheffield Utd', 1020),
#  ('Southampton', 1110),
#  ('Spurs', 1260),
#  ('West Brom', 990),
#  ('West Ham', 1160),
#  ('Wolves', 1140)]

# %%
bootstrap_static['elements'][42]
# Out:
# {'chance_of_playing_next_round': 75,
#  'chance_of_playing_this_round': 75,
#  'code': 193488,
#  'cost_change_event': 0,
#  'cost_change_event_fall': 0,
#  'cost_change_start': 0,
#  'cost_change_start_fall': 0,
#  'dreamteam_count': 0,
#  'element_type': 3,
#  'ep_next': '1.0',
#  'ep_this': '0.0',
#  'event_points': 0,
#  'first_name': 'Anwar',
#  'form': '2.3',
#  'id': 30,
#  'in_dreamteam': False,
#  'news': 'Knock - 75% chance of playing',
#  'news_added': '2020-02-22T17:30:19.276253Z',
#  'now_cost': 55,
#  'photo': '193488.jpg',
#  'points_per_game': '3.2',
#  'second_name': 'El Ghazi',
#  'selected_by_percent': '0.8',
#  'special': False,
#  'squad_number': None,
#  'status': 'd',
#  'team': 2,
#  'team_code': 7,
#  'total_points': 78,
#  'transfers_in': 253720,
#  'transfers_in_event': 25,
#  'transfers_out': 238946,
#  'transfers_out_event': 461,
#  'value_form': '0.4',
#  'value_season': '14.2',
#  'web_name': 'El Ghazi',
#  'minutes': 1646,
#  'goals_scored': 4,
#  'assists': 5,
#  'clean_sheets': 4,
#  'goals_conceded': 38,
#  'own_goals': 0,
#  'penalties_saved': 0,
#  'penalties_missed': 0,
#  'yellow_cards': 3,
#  'red_cards': 0,
#  'saves': 0,
#  'bonus': 0,
#  'bps': 235,
#  'influence': '347.6',
#  'creativity': '421.2',
#  'threat': '586.0',
#  'ict_index': '135.5'}

# %%
# bootstrap-static
element_summ = json.loads(session.get('https://fantasy.premierleague.com/api/element-summary/30/').text)

# %%
element_summ.keys()
# Out:
# dict_keys(['fixtures', 'history', 'history_past'])

# %%
element_summ['history'][-1]
# Out:
# {'element': 30,
#  'fixture': 269,
#  'opponent_team': 16,
#  'total_points': 1,
#  'was_home': False,
#  'kickoff_time': '2020-02-22T15:00:00Z',
#  'team_h_score': 2,
#  'team_a_score': 0,
#  'round': 27,
#  'minutes': 27,
#  'goals_scored': 0,
#  'assists': 0,
#  'clean_sheets': 0,
#  'goals_conceded': 1,
#  'own_goals': 0,
#  'penalties_saved': 0,
#  'penalties_missed': 0,
#  'yellow_cards': 0,
#  'red_cards': 0,
#  'saves': 0,
#  'bonus': 0,
#  'bps': 5,
#  'influence': '3.2',
#  'creativity': '5.6',
#  'threat': '2.0',
#  'ict_index': '1.1',
#  'value': 55,
#  'transfers_balance': -709,
#  'selected': 66047,
#  'transfers_in': 2540,
#  'transfers_out': 3249}
