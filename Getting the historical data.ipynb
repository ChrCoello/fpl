# %%
import requests
import json
import os
import datetime

session = requests.Session()


# bootstrap-static
bootstrap_static = json.loads(session.get('https://fantasy.premierleague.com/api/bootstrap-static/').text)
bootstrap_static["_id"] = datetime.datetime.utcnow()

# %%
bootstrap_static.keys()
# Out:
# dict_keys(['events', 'game_settings', 'phases', 'teams', 'total_players', 'elements', 'element_stats', 'element_types', '_id'])

# %%
bootstrap_static['teams']
# Out:
# [{'code': 3,
#   'draw': 0,
#   'form': None,
#   'id': 1,
#   'loss': 0,
#   'name': 'Arsenal',
#   'played': 0,
#   'points': 0,
#   'position': 0,
#   'short_name': 'ARS',
#   'strength': 4,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1230,
#   'strength_overall_away': 1270,
#   'strength_attack_home': 1150,
#   'strength_attack_away': 1190,
#   'strength_defence_home': 1280,
#   'strength_defence_away': 1330},
#  {'code': 7,
#   'draw': 0,
#   'form': None,
#   'id': 2,
#   'loss': 0,
#   'name': 'Aston Villa',
#   'played': 0,
#   'points': 0,
#   'position': 0,
#   'short_name': 'AVL',
#   'strength': 2,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1040,
#   'strength_overall_away': 1080,
#   'strength_attack_home': 1030,
#   'strength_attack_away': 1060,
#   'strength_defence_home': 1030,
#   'strength_defence_away': 1050},
#  {'code': 91,
#   'draw': 0,
#   'form': None,
# ...

# %%
bootstrap_static['elements'][42]
# Out:
# {'chance_of_playing_next_round': 75,
#  'chance_of_playing_this_round': 75,
#  'code': 193488,
#  'cost_change_event': 0,
#  'cost_change_event_fall': 0,
#  'cost_change_start': 0,
#  'cost_change_start_fall': 0,
#  'dreamteam_count': 0,
#  'element_type': 3,
#  'ep_next': '1.0',
#  'ep_this': '0.0',
#  'event_points': 0,
#  'first_name': 'Anwar',
#  'form': '2.3',
#  'id': 30,
#  'in_dreamteam': False,
#  'news': 'Knock - 75% chance of playing',
#  'news_added': '2020-02-22T17:30:19.276253Z',
#  'now_cost': 55,
#  'photo': '193488.jpg',
#  'points_per_game': '3.2',
#  'second_name': 'El Ghazi',
#  'selected_by_percent': '0.8',
#  'special': False,
#  'squad_number': None,
#  'status': 'd',
#  'team': 2,
#  'team_code': 7,
#  'total_points': 78,
#  'transfers_in': 253720,
#  'transfers_in_event': 25,
#  'transfers_out': 238946,
#  'transfers_out_event': 461,
#  'value_form': '0.4',
#  'value_season': '14.2',
#  'web_name': 'El Ghazi',
#  'minutes': 1646,
#  'goals_scored': 4,
# ...

# %%
# bootstrap-static
element_summ = json.loads(session.get('https://fantasy.premierleague.com/api/element-summary/30/').text)

# %%
element_summ.keys()
# Out:
# dict_keys(['fixtures', 'history', 'history_past'])

# %%
element_summ['history'][-1]
# Out:
# {'element': 30,
#  'fixture': 269,
#  'opponent_team': 16,
#  'total_points': 1,
#  'was_home': False,
#  'kickoff_time': '2020-02-22T15:00:00Z',
#  'team_h_score': 2,
#  'team_a_score': 0,
#  'round': 27,
#  'minutes': 27,
#  'goals_scored': 0,
#  'assists': 0,
#  'clean_sheets': 0,
#  'goals_conceded': 1,
#  'own_goals': 0,
#  'penalties_saved': 0,
#  'penalties_missed': 0,
#  'yellow_cards': 0,
#  'red_cards': 0,
#  'saves': 0,
#  'bonus': 0,
#  'bps': 5,
#  'influence': '3.2',
#  'creativity': '5.6',
#  'threat': '2.0',
#  'ict_index': '1.1',
#  'value': 55,
#  'transfers_balance': -709,
#  'selected': 66047,
#  'transfers_in': 2540,
#  'transfers_out': 3249}
